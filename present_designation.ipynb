# %%
import os
import docx
import PyPDF2
import pandas as pd

# Specify the folder path containing the Word documents and PDFs
folder_path = "D:\\Work_A"

# Specify the order of designations from higher to lower
designation_order = [
 "President",
 "Vice President",
 "Assistant Vice President",
 "Branch President",
 "Brach Supervisor",
 "Branch Head",
 "Senior Manager",
 "Sr Manager",
 "Senior Bank Officer",
 "Senior Officer",
 "Senior Sales Officer",
 "Senior Account Officer",
 "Sr Area Business Executive",
 "Senior Relationship Manager",
 "Senior Customer Service Executive",
 "Senior Processing Officer",
 "Branch Manager",
 "Branch Credit Manager"
 "Deputy Branch Manager",
 "Deputy Manager",
 "Assistant Branch Manager",
 "Assistant Manager",
 "Team Manager",
 "Team Leader",
 "Team Leader(Sales & Marketing)",
 "Asset & Wealth Manager",
 "Asset Desk Manager",
 "Wealth Manager",
 "Portfolio Manager",
 "Assistant Portfolio Manager",
 "Assistant Portfolio Manager-Sales",
 "Credit & Risk Analyst",
 "Credit Analyst",
 "Analyst",
 "Branch Operations Manager",
 "Branch Sales Manager",
 "Area Business Manager",
 "Area Manager", 
 "Area Retail Officer",
 "Area Officer",
 "Business Developpment Executive",
 "Desk Manager",
 "Desk Officer",
 "Processing Executive",
 "Process Associate",
 "Aquisition Manager",
 "Assistant Aquisition Manager",
 "Bank Assurance Officer",
 "Privilege Banker",
 "Personal Banker",
 "Sales Executive",
 "Sales Manager",
 "Associate Sales Manager",
 "Sales Officer",
 "Branch Sales Officer",
 "Sales & Marketing Officer",
 "CASA Sales Officer",
 "Sales Representative",
 "Marketing Executive",
 "Marketing Officer",
 "Business Sales Manager",
 "Unit Sales Manager",
 "Assistant Sales Executive",
 "Field Sales Executive",
 "Retail Sales Executive",
 "Junior Sales Executive",
 "Tele Sales Officer",
 "Sales Promoter",
 "Brand Promoter",
 "Category Head Promoter",
 "Store Manager",
 "Assistant Store Manager",
 "SSE - Store Sales Executive",
 "Sales Trainee",
 "Operations Manager",
 "Financial Planner",
 "Associate Financial Service Manager",
 "Financial Consultant",
 "Investment Advisor",
 "Key Relationship Manager",
 "Relationship Executive",
 "Relationship Manager",
 "Relationship Officer",
 "Assistant Relationship Manager",
 "Customer Relationship Manager",
 "Digital Relationship Manager",
 "E - Relationship Manager",
 "Assistant E - Relationship Manager",
 "Customer Service Manager",
 "Customer Service Officer",
 "Customer Representative Manager",
 "Customer Service Executive",
 "Customer Service Associate",
 "Citizen Service Executive",
 "CSR Executive",
 "Front Office Executive",
 "Account Manager ",
 "Key Account Manager",
 "Accounts Officer",
 "Accounts Incharge",
 "Accountant",
 "Assistant Accountant",
 "Employee Welfare Officer",
 "Contract Administrative Employee",
 "Agency Developpment Manager",
 "Corporate Agency Manager",
 "Agency Manager",
 "Diploma Engineering Trainee",
 "Extreme Fiber Executive",
 "Senior Fashion Consultant",
 "Fashion Consultant",
 "Fashion Advisor",
 "Patient's Care Executive",
 "Technician"
  ]


# Initialize variables to store the highest designation and file name
highest_designation = ""
highest_designation_file = ""

# Iterate over all files in the folder
for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)
    
    # Check if the file is a Word document
    if file_name.endswith(".docx"):
        doc = docx.Document(file_path)
        text = " ".join([paragraph.text for paragraph in doc.paragraphs])
    
    # Check if the file is a PDF
    elif file_name.endswith(".pdf"):
        with open(file_path, "rb") as file:
            reader = PyPDF2.PdfFileReader(file)
            num_pages = reader.numPages
            text = ""
            for page_num in range(num_pages):
                page = reader.getPage(page_num)
                text += page.extract_text()
    
    # Process the text to find the highest designation
    for designation in designation_order:
        if designation.lower() in text.lower():
            highest_designation = designation
            highest_designation_file = file_name
            break

    # Print the designation and file name for the current file
    print(f"File: {file_name} | Designation: {highest_designation}")
    print()
# Out:
# File: Abhijeet_rexwal.docx | Designation: Portfolio Manager
#
# File: AK_khan.docx | Designation: Senior Fashion Consultant
#
# File: Amankumar_Akurada.docx | Designation: Sales Executive
#
# File: Aman_Bharadwaj.docx | Designation: Senior Sales Officer
#
# File: Amit_Tekwani.pdf | Designation: Analyst
#
# File: aneel_sahoo.docx | Designation: Senior Officer
#
# File: Anish_Kumar.docx | Designation: Relationship Manager
#
# File: Aruna_kumari.docx | Designation: Assistant Manager
#
# File: Ashok_baba.docx | Designation: Sales Executive
#
# File: Asit_paul.docx | Designation: Assistant Manager
#
# File: Aspathwar_naresh.docx | Designation: Sales Officer
#
# File: atul_sharma.docx | Designation: Branch Manager
#
# File: babasreeta_mishra.docx | Designation: Branch Manager
#
# File: Bhakti_parmar.pdf | Designation: Branch Manager
#
# File: bhavna_mulchandani.pdf | Designation: Branch Manager
#
# File: biswaranjan_kar.docx | Designation: Branch Manager
#
# ...

# %%
import pandas as pd

# File list
file_list = [
    "Abhijeet_rexwal.docx | Designation: Portfolio Manager",
    "AK_khan.docx | Designation: Senior Fashion Consultant",
    "Amankumar_Akurada.docx | Designation: Sales Executive",
    "Aman_Bharadwaj.docx | Designation: Senior Sales Officer",
    "Amit_Tekwani.pdf | Designation: Analyst",
    "aneel_sahoo.docx | Designation: Senior Officer",
    "Anish_Kumar.docx | Designation: Relationship Manager",
    "Aruna_kumari.docx | Designation: Assistant Manager",
    "Ashok_baba.docx | Designation: Sales Executive",
    "Asit_paul.docx | Designation: Assistant Manager",
    "Aspathwar_naresh.docx | Designation: Sales Officer",
    "atul_sharma.docx | Designation: Branch Manager",
    "babasreeta_mishra.docx | Designation: Branch Manager",
    "Bhakti_parmar.pdf | Designation: Branch Manager",
    "bhavna_mulchandani.pdf | Designation: Branch Manager",
    "biswaranjan_kar.docx | Designation: Branch Manager",
    "Boudhuru_satishkumar.pdf | Designation: Branch Manager",
    "Chandrakant_sahebrao_kanade.docx | Designation: Senior Officer",
    "Chirag_Bhatt.docx | Designation: Senior Relationship Manager",
    "Deepakkumar_Patnaik.docx | Designation: Assistant Manager",
    "Golajana_Ravi.docx | Designation: Assistant Manager",
    "Hamid_Zarger.docx | Designation: Bank Assurance Officer",
    "Hemant_Sharma.pdf | Designation: Area Business Manager",
    "Hema_Singh.docx | Designation: Assistant Manager",
    "Ippli_Chanti.docx | Designation: Relationship Officer",
    "Israr_Ali.docx | Designation: Senior Bank Officer",
    "Javedakhtar_Chaudhri.docx | Designation: Relationship Manager",
    "Jeetendra_Kumar.docx | Designation: Sales Representative",
    "Kalpana_Sk.pdf | Designation: Sales Representative",
    "karthikeyan.docx | Designation: Process Associate",
    "Kaustabh_Manjrekar.docx | Designation: Area Manager",
    "Kavya_Santoshkumar.docx | Designation: Personal Banker",
    "Kiran_s.docx | Designation: Assistant Manager",
    "Krishan_Shekhawat.docx | Designation: Sales & Marketing Officer",
    "Kushal_Agrawal.docx | Designation: Relationship Manager",
    "Laxmanrao_MyCharla.pdf | Designation: Relationship Manager",
    "Mahesh_Ayyappa.docx | Designation: Team Leader",
    "Mahesh_balukolhe.docx | Designation: Sales Executive",
    "Mane_Gopal.docx | Designation: Sales Manager",
    "Manisha_Prasad.docx | Designation: Senior Relationship Manager",
    "Mohammad_baig.docx | Designation: Sales Executive",
    "Monica_kinger.pdf | Designation: Wealth Manager",
    "Mouli_karnaparthi.docx | Designation: Sales Manager",
    "Mustak_abbigairi.pdf | Designation: Sales Manager",
    "Nana_Dungarnath_Bhandari.docx | Designation: Deputy Manager",
    "Neelmani_Arora.docx | Designation: Senior Officer",
    "Neetu_Kumar.docx | Designation: Senior Officer",
    "Nikshita_B.docx | Designation: Assistant Manager",
    "nirakar_sahoo.docx | Designation: Senior Manager",
    "Nityananda.docx | Designation: Analyst",
    "N_Sandiya.pdf | Designation: Analyst",
    "pankaj_sahoo.docx | Designation: Branch Head",
    "Parvezuddin.docx | Designation: Sales Executive",
    "Patha_Chaterjee.docx | Designation: Senior Relationship Manager",
    "prabhudatta_das.pdf | Designation: Branch Manager",
    "Pratik_Shelke.docx | Designation: Deputy Manager",
    "Premkumar_M.docx | Designation: Senior Customer Service Executive",
    "Pritam_Das.docx | Designation: Deputy Manager",
    "priyanka_gupta.docx | Designation: Branch Manager",
    "Rachabanti_shivkrishna.pdf | Designation: Sales Executive",
    "rajeev_soni.docx | Designation: Branch Manager",
    "rajeshkumar_dora.docx | Designation: Branch Head",
    "Raman_mishra.docx | Designation: Sales Officer",
    "Ravilla_Jagdish.docx | Designation: Credit & Risk Analyst",
    "Ravi_kumar.docx | Designation: Branch Manager",
    "ritesh_mishra.docx | Designation: Branch Manager",
    "Sagar_Dhanna.pdf | Designation: Assistant Manager",
    "Samabraju_naveen.pdf | Designation: Store Manager",
    "sambit_chaudhri.docx | Designation: Branch Manager",
    "Sanchita.docx | Designation: Assistant Manager",
    "sanjeev_banerjee.docx | Designation: Senior Manager",
    "sanket_sharma.pdf | Designation: Senior Manager",
    "santosh_nanda.docx | Designation: Branch Manager",
    "Santosh_Singh_A.pdf | Designation: Sales Manager",
    "Santosh_Singh_B.docx | Designation: Sales Manager",
    "saptdeep_guha.docx | Designation: Branch Head",
    "saroj_mahapatra.docx | Designation: Branch Manager",
    "Satish_Kumar.docx | Designation: Sales Executive",
    "saumitra_tripathy.docx | Designation: Branch Manager",
    "Sd_Yakub_Paasha.docx | Designation: Sales Officer",
    "Shabeer_Mulla.pdf | Designation: Sales Officer",
    "Shaik_Rehman.pdf | Designation: Sales Executive",
    "Shashank_Paliwaal.docx | Designation: Sales Manager",
    "Shubhangi_Singh.docx | Designation: Sales Manager",
    "Sivannarayana_M.docx | Designation: Senior Processing Officer",
    "Sonal_Anand.docx | Designation: Senior Relationship Manager",
    "sumant_biswal.docx | Designation: Branch Head",
    "sumeet_raut.docx | Designation: President",
    "Susanth_Koro.docx | Designation: Senior Officer",
    "Syam_Sunder.docx | Designation: Branch Manager",
    "Tabraiz_Mehdi.docx | Designation: Sales Representative",
    "tushar_mathur.docx | Designation: Branch Manager",
    "Vikash_anand.docx | Designation: Sales Executive",
    "Vikash_Sharma.pdf | Designation: Branch Manager",
    "Vikrant_Singh.docx | Designation: Acquisition Manager",
    "Vishwa_Teja_Tiruvairupati.docx | Designation: Relationship Manager",
    "Vivek_Singh.pdf | Designation: Relationship Manager"
]

# Create a DataFrame
data = {'File': [], 'Designation': []}
for file in file_list:
    file_name, designation = file.split(" | ")
    data['File'].append(file_name)
    data['Designation'].append(designation)

df = pd.DataFrame(data)

# Save DataFrame to Excel
df.to_excel('present_designation.xlsx', index=False)

# %%
df
# Out:
#                               File                             Designation
# 0             Abhijeet_rexwal.docx          Designation: Portfolio Manager
# 1                     AK_khan.docx  Designation: Senior Fashion Consultant
# 2           Amankumar_Akurada.docx            Designation: Sales Executive
# 3              Aman_Bharadwaj.docx       Designation: Senior Sales Officer
# 4                 Amit_Tekwani.pdf                    Designation: Analyst
# ..                             ...                                     ...
# 92               Vikash_anand.docx            Designation: Sales Executive
# 93               Vikash_Sharma.pdf             Designation: Branch Manager
# 94              Vikrant_Singh.docx        Designation: Acquisition Manager
# 95  Vishwa_Teja_Tiruvairupati.docx       Designation: Relationship Manager
# 96                 Vivek_Singh.pdf       Designation: Relationship Manager
#
# [97 rows x 2 columns]
